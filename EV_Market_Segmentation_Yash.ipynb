# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
smev = pd.read_excel('/content/smev_data.xlsx', sheet_name=None)
smev.keys()
# Out:
# dict_keys(['EV 2W FY 19-20', 'EV 2W FY 20-21', 'EV 2W FY 21-22', 'EV 2W FY 22-23', 'EV Market', 'Electric Bus Sales', 'Electric 4-Wheeler Sales', 'Electric 3-Wheeler Sales', 'Electric 2-Wheeler Sales', 'EV Industries'])

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.lineplot(
    data=smev['EV 2W FY 19-20'],
    x='month',
    y='num_vehicles',
    hue='maker',
    style='financial_year',
    markers=True,
    dashes=False
)
plt.title("Trends Over Months")
plt.xlabel("Month")
plt.ylabel("No. of Vehicles")
plt.legend(title='Maker')
plt.grid(True)
plt.show()

# %%
smev['EV 2W FY 20-21'].info()
plt.figure(figsize=(10, 6))
sns.lineplot(
    data=smev['EV 2W FY 20-21'],
    x='month',
    y='num_vehicles',
    hue='maker',
    style='financial_year',
    markers=True,
    dashes=False
)
plt.title("Trends Over Months")
plt.xlabel("Month")
plt.ylabel("No. of Vehicles")
plt.legend(title='Maker')
plt.grid(True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   financial_year  132 non-null    object
#  1   maker           132 non-null    object
#  2   market_share    132 non-null    float64
#  3   month           132 non-null    object
#  4   num_vehicles    132 non-null    int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 5.3+ KB

# %%
smev['EV 2W FY 21-22'].info()
plt.figure(figsize=(10, 6))
sns.lineplot(
    data=smev['EV 2W FY 21-22'],
    x='month',
    y='num_vehicles',
    hue='maker',
    style='financial_year',
    markers=True,
    dashes=False
)
plt.title("Trends Over Months")
plt.xlabel("Month")
plt.ylabel("No. of Vehicles")
plt.legend(title='Maker')
plt.grid(True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   financial_year  144 non-null    object
#  1   maker           144 non-null    object
#  2   market_share    144 non-null    float64
#  3   month           144 non-null    object
#  4   num_vehicles    144 non-null    int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 5.8+ KB

# %%
smev['EV 2W FY 22-23'].info()
plt.figure(figsize=(15, 6))
sns.lineplot(
    data=smev['EV 2W FY 22-23'],
    x='month',
    y='num_vehicles',
    hue='maker',
    style='financial_year',
    markers=True,
    dashes=False
)
plt.title("Trends Over Months")
plt.xlabel("Month")
plt.ylabel("No. of Vehicles")
plt.legend(title='Maker')
plt.grid(True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   financial_year  156 non-null    object
#  1   maker           156 non-null    object
#  2   market_share    156 non-null    float64
#  3   month           156 non-null    object
#  4   num_vehicles    156 non-null    int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 6.2+ KB

# %%
smev['EV Market'].info()
plt.figure(figsize=(8, 6))
sns.barplot(data=smev['EV Market'], x='Category', y='Amount INR Cr', palette='viridis')
plt.title("Amount Distribution by Category")
plt.xlabel("Category")
plt.ylabel("Amount (INR Cr)")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Category       4 non-null      object
#  1   Amount INR Cr  4 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 192.0+ bytes
# <ipython-input-21-64b6d4f0d37d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=smev['EV Market'], x='Category', y='Amount INR Cr', palette='viridis')

# %%
smev['Electric Bus Sales'].info()
plt.figure(figsize=(15, 6))
sns.lineplot(
    data=smev['Electric Bus Sales'],
    x='month',
    y='num_vehicles',
    hue='financial_year',
    style='type',
    markers=True,
    dashes=False
)
plt.title("Trends Over Months")
plt.xlabel("Month")
plt.ylabel("No. of Vehicles")
plt.legend(title='Type')
plt.grid(True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   type            72 non-null     object
#  1   financial_year  72 non-null     object
#  2   month           72 non-null     object
#  3   num_vehicles    72 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 2.4+ KB

# %%
smev['Electric 4-Wheeler Sales'].info()
plt.figure(figsize=(15, 6))
sns.lineplot(
    data=smev['Electric 4-Wheeler Sales'],
    x='month',
    y='num_vehicles',
    hue='financial_year',
    style='type',
    markers=True,
    dashes=False
)
plt.title("Trends Over Months")
plt.xlabel("Month")
plt.ylabel("No. of Vehicles")
plt.legend(title='Type')
plt.grid(True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   type            72 non-null     object
#  1   financial_year  72 non-null     object
#  2   month           72 non-null     object
#  3   num_vehicles    72 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 2.4+ KB

# %%
smev['Electric 3-Wheeler Sales'].info()
plt.figure(figsize=(15, 6))
sns.lineplot(
    data=smev['Electric 3-Wheeler Sales'],
    x='month',
    y='num_vehicles',
    hue='financial_year',
    style='type',
    markers=True,
    dashes=False
)
plt.title("Trends Over Months")
plt.xlabel("Month")
plt.ylabel("No. of Vehicles")
plt.legend(title='Type')
plt.grid(True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   type            72 non-null     object
#  1   financial_year  72 non-null     object
#  2   month           72 non-null     object
#  3   num_vehicles    72 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 2.4+ KB

# %%
smev['Electric 2-Wheeler Sales'].info()
plt.figure(figsize=(15, 6))
sns.lineplot(
    data=smev['Electric 2-Wheeler Sales'],
    x='month',
    y='num_vehicles',
    hue='financial_year',
    style='type',
    markers=True,
    dashes=False
)
plt.title("Trends Over Months")
plt.xlabel("Month")
plt.ylabel("No. of Vehicles")
plt.legend(title='Type')
plt.grid(True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   type            72 non-null     object
#  1   financial_year  72 non-null     object
#  2   month           72 non-null     object
#  3   num_vehicles    72 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 2.4+ KB

# %%
smev['EV Industries'].info()
fig, ax = plt.subplots(figsize=(6, 4))
ax = sns.lineplot(data=smev['EV Industries'], x='financial_year', y='num_vehicles', hue='category', marker='o', palette='tab10')
plt.xlabel("Financial Year")
plt.ylabel("Vehicles")
plt.legend(title='Category')

# Annotate the last data point
for col in smev['EV Industries']['category'].unique():
    last_point = smev['EV Industries'][smev['EV Industries']['category'] == col].iloc[-1]
    plt.annotate(f"{last_point['category']}",
                 (last_point['financial_year'], last_point['num_vehicles']),
                 textcoords="offset points",
                 xytext=(10, -5),
                 ha='left')
ax.spines[['right', 'top']].set_visible(False)
ax.get_legend().set_visible(False)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   category        24 non-null     object
#  1   financial_year  24 non-null     object
#  2   num_vehicles    24 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 704.0+ bytes

# %%
EV_2W = list(smev.keys())[0:4]
data_EV_2W = pd.concat([smev[EV_2W[0]], smev[EV_2W[1]], smev[EV_2W[2]], smev[EV_2W[3]]])

# %%
data_EV_2W['maker'] = data_EV_2W['maker'].str.upper()

# %%
data_EV_2W['maker'] = data_EV_2W['maker'].replace('AMPERE VEHICLES', 'AMPERE').replace('ATHER ENERGY', 'ATHER').replace('BEING INDIA', 'BENLING').replace('JITENDRA NEW EV', 'JITENDRA').replace('OKINAWA AUTOTECH', 'OKINAWA')

# %%
data_EV_2W
# Out:
#     financial_year          maker  market_share  month  num_vehicles
# 0          2019-20  HERO ELECTRIC          0.30    Apr          1776
# 1          2019-20  HERO ELECTRIC          0.30    May           455
# 2          2019-20  HERO ELECTRIC          0.30    Jun           329
# 3          2019-20  HERO ELECTRIC          0.30    Jul           260
# 4          2019-20  HERO ELECTRIC          0.30    Aug           249
# ..             ...            ...           ...    ...           ...
# 151        2022-23         OTHERS          0.08    Nov          5241
# 152        2022-23         OTHERS          0.08    Dec          5233
# 153        2022-23         OTHERS          0.08    Jan          5111
# 154        2022-23         OTHERS          0.08    Feb          5083
# 155        2022-23         OTHERS          0.08  March          7562
#
# [504 rows x 5 columns]

# %%
data_EV_2W_year = data_EV_2W.groupby(['financial_year', 'maker']).agg({'num_vehicles':'sum'}).reset_index()

# %%
fig, ax = plt.subplots(figsize=(6,8))
ax = sns.lineplot(data=data_EV_2W_year, x='financial_year', y='num_vehicles', hue='maker', marker='o', palette='tab10')
plt.xlabel("Financial Year", fontsize = 15)
plt.ylabel("Vehicles", fontsize = 15)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.legend(title='Maker')

# Annotate the last data point
for col in data_EV_2W_year['maker'].unique()[::1]:
    last_point = data_EV_2W_year[data_EV_2W_year['maker'] == col].iloc[-1]
    plt.annotate(f"{last_point['maker']}",
                 (last_point['financial_year'], last_point['num_vehicles']),
                 textcoords="offset points",
                 xytext=(10, -5),
                 ha='left')
ax.spines[['right', 'top']].set_visible(False)
ax.get_legend().set_visible(False)
plt.show()

# %% [markdown]
# # **MARKET SEGMENTATION BASED ON BIKEWALE DATA**

# %%
data_bw = pd.read_csv("/content/ev2_bikewale.csv")
data_model = pd.read_csv("/content/ev_model_spec.csv")
data = data_bw.merge(data_model, how = 'left', on = 'Model Name')

# %%
data.head()
# Out:
#                                               review    Used it for  \
# 0  We all checked the bike's capacity to be 150 k...  Daily Commute
# 1  Performance is very poor on this bike. The cha...     Everything
# 2  I purchased this in April 2022 and the sales s...  Daily Commute
# 3  If any issues come in scooty parts not availab...  Daily Commute
# 4  Don't buy this vehicle unless you have a near ...  Daily Commute
#
#        Owned for      Ridden for  rating  Visual Appeal  Reliability  \
# 0    Never owned             NaN       1            3.0          4.0
# 1         > 1 yr      < 5000 kms       1            3.0          1.0
# 2     < 3 months      < 5000 kms       3            4.0          4.0
# 3  6 months-1 yr  5000-10000 kms       1            1.0          1.0
# 4  6 months-1 yr      < 5000 kms       1            3.0          4.0
#
#    Performance  Service Experience  Extra Features  Comfort  Maintenance cost  \
# 0          NaN                 NaN             NaN      4.0               NaN
# 1          NaN                 1.0             NaN      3.0               NaN
# 2          NaN                 2.0             NaN      5.0               NaN
# 3          NaN                 1.0             NaN      1.0               NaN
# 4          NaN                 1.0             NaN      3.0               NaN
#
#    Value for Money Model Name   Price  Riding Range (km)  Top Speed (kmph)  \
# 0              1.0  TVS iQube  137890                100                78
# 1              3.0  TVS iQube  137890                100                78
# 2              2.0  TVS iQube  137890                100                78
# 3              1.0  TVS iQube  137890                100                78
# 4              2.0  TVS iQube  137890                100                78
#
#    Weight (kg)  Battery Charging Time (hrs)  Rated Power (W)
# 0          117                            5             3000
# 1          117                            5             3000
# 2          117                            5             3000
# 3          117                            5             3000
# 4          117                            5             3000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 844 entries, 0 to 843
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   review                       797 non-null    object
#  1   Used it for                  844 non-null    object
#  2   Owned for                    844 non-null    object
#  3   Ridden for                   668 non-null    object
#  4   rating                       844 non-null    int64
#  5   Visual Appeal                739 non-null    float64
#  6   Reliability                  716 non-null    float64
#  7   Performance                  345 non-null    float64
#  8   Service Experience           703 non-null    float64
#  9   Extra Features               185 non-null    float64
#  10  Comfort                      530 non-null    float64
#  11  Maintenance cost             180 non-null    float64
#  12  Value for Money              390 non-null    float64
#  13  Model Name                   844 non-null    object
#  14  Price                        844 non-null    int64
#  15  Riding Range (km)            844 non-null    int64
#  16  Top Speed (kmph)             844 non-null    int64
#  17  Weight (kg)                  844 non-null    int64
#  18  Battery Charging Time (hrs)  844 non-null    int64
#  19  Rated Power (W)              844 non-null    int64
# dtypes: float64(8), int64(7), object(5)
# memory usage: 132.0+ KB

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=data, x='Model Name', y='Price', palette='viridis')
plt.title("Price by Model Name")
plt.xlabel("Model Name")
plt.ylabel("Price (INR)")
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-46-bb8c47302103>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data, x='Model Name', y='Price', palette='viridis')

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
sentiments = SentimentIntensityAnalyzer()
sentiments_list = []

for review_text in data['review']:
    if pd.isna(review_text):
        sentiments_list.append('neutral')
        continue
    sentiment_scores = sentiments.polarity_scores(review_text)

    positive_score = sentiment_scores['pos']
    negative_score = sentiment_scores['neg']

    if positive_score > negative_score:
        sentiment_label = 'positive'
    elif positive_score < negative_score:
        sentiment_label = 'negative'
    else:
        sentiment_label = 'neutral'

    sentiments_list.append(sentiment_label)

data['sentiment'] = sentiments_list

# %%
data.head()
# Out:
#                                               review    Used it for  \
# 0  We all checked the bike's capacity to be 150 k...  Daily Commute
# 1  Performance is very poor on this bike. The cha...     Everything
# 2  I purchased this in April 2022 and the sales s...  Daily Commute
# 3  If any issues come in scooty parts not availab...  Daily Commute
# 4  Don't buy this vehicle unless you have a near ...  Daily Commute
#
#        Owned for      Ridden for  rating  Visual Appeal  Reliability  \
# 0    Never owned             NaN       1            3.0          4.0
# 1         > 1 yr      < 5000 kms       1            3.0          1.0
# 2     < 3 months      < 5000 kms       3            4.0          4.0
# 3  6 months-1 yr  5000-10000 kms       1            1.0          1.0
# 4  6 months-1 yr      < 5000 kms       1            3.0          4.0
#
#    Performance  Service Experience  Extra Features  ...  Maintenance cost  \
# 0          NaN                 NaN             NaN  ...               NaN
# 1          NaN                 1.0             NaN  ...               NaN
# 2          NaN                 2.0             NaN  ...               NaN
# 3          NaN                 1.0             NaN  ...               NaN
# 4          NaN                 1.0             NaN  ...               NaN
#
#    Value for Money  Model Name   Price  Riding Range (km)  Top Speed (kmph)  \
# 0              1.0   TVS iQube  137890                100                78
# 1              3.0   TVS iQube  137890                100                78
# 2              2.0   TVS iQube  137890                100                78
# 3              1.0   TVS iQube  137890                100                78
# 4              2.0   TVS iQube  137890                100                78
#
#    Weight (kg)  Battery Charging Time (hrs)  Rated Power (W)  sentiment
# 0          117                            5             3000   negative
# 1          117                            5             3000   negative
# 2          117                            5             3000   positive
# 3          117                            5             3000   negative
# 4          117                            5             3000   negative
#
# [5 rows x 21 columns]

# %%
data['sentiment'].value_counts()
# Out:
# sentiment
# positive    527
# negative    264
# neutral      53
# Name: count, dtype: int64

# %%
data_segment = data[['Used it for', 'Owned for', 'Ridden for', 'rating',
       'Visual Appeal', 'Reliability', 'Performance', 'Service Experience',
       'Extra Features', 'Comfort', 'Maintenance cost', 'Value for Money',
       'sentiment']].copy()

# %%
data_segment = data.iloc[:, 5:13].copy()

# %%
data_segment = data_segment.fillna(0.)

# %%
data_segment.mean()
# Out:
# Visual Appeal         3.309242
# Reliability           2.811611
# Performance           1.441943
# Service Experience    2.619668
# Extra Features        0.643365
# Comfort               2.300948
# Maintenance cost      0.723934
# Value for Money       1.562796
# dtype: float64

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_segment)

# %%
pca = PCA(random_state = 42)
pca.fit(data_scaled)
# Out:
# PCA(random_state=42)

# %%
data_pca = pca.transform(data_scaled)

# %%
df_pca = pd.DataFrame(data_pca, columns = [f'PC{x +1}' for x in range(len(data_segment.columns))])

# %%
df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -0.291227 -1.038055  0.354864  0.623469  1.102720  0.169287  0.438012
# 1 -0.710801 -1.394405 -0.360466  0.621671 -0.320899  0.086053  0.426279
# 2  0.849149 -1.189765  0.167683  0.410898  0.409054  0.191904  0.329993
# 3 -1.967022 -0.878935 -0.100197 -0.330003  0.075822 -0.069599 -0.013068
# 4 -0.078940 -1.017161 -0.079210  0.324132  0.961554 -0.005517  0.107260
#
#         PC8
# 0 -0.957827
# 1  0.149917
# 2 -0.830738
# 3 -0.011328
# 4 -0.427972

# %%
pca_summary = pd.DataFrame({'Standard Deviation':df_pca.std(),
                           'Proportion of Variance': pca.explained_variance_ratio_,
                           'Cumultive Proportion': pca.explained_variance_ratio_.cumsum()})

# %%
pca_summary
# Out:
#      Standard Deviation  Proportion of Variance  Cumultive Proportion
# PC1            1.845017                0.425007              0.425007
# PC2            1.736646                0.376546              0.801553
# PC3            0.903486                0.101915              0.903468
# PC4            0.517750                0.033468              0.936936
# PC5            0.405239                0.020503              0.957439
# PC6            0.379558                0.017987              0.975426
# PC7            0.337883                0.014254              0.989680
# PC8            0.287510                0.010320              1.000000

# %%
factor_loadings = pd.DataFrame(pca.components_, columns = data_segment.columns, index = df_pca.columns).T

# %%
factor_loadings.style.background_gradient(cmap = 'RdGy')
# Out:
# <style type="text/css">
# #T_41dd2_row0_col0 {
#   background-color: #282828;
#   color: #f1f1f1;
# }
# #T_41dd2_row0_col1 {
#   background-color: #f3f3f3;
#   color: #000000;
# }
# #T_41dd2_row0_col2, #T_41dd2_row1_col1, #T_41dd2_row7_col3 {
#   background-color: #f0f0f0;
#   color: #000000;
# }
# #T_41dd2_row0_col3, #T_41dd2_row1_col0, #T_41dd2_row1_col4, #T_41dd2_row2_col2, #T_41dd2_row4_col1, #T_41dd2_row5_col6, #T_41dd2_row6_col5, #T_41dd2_row7_col7 {
#   background-color: #1a1a1a;
#   color: #f1f1f1;
# }
# #T_41dd2_row0_col4, #T_41dd2_row4_col2 {
#   background-color: #cc4c44;
#   color: #f1f1f1;
# }
# #T_41dd2_row0_col5, #T_41dd2_row6_col7 {
#   background-color: #f8bb9e;
#   color: #000000;
# }
# #T_41dd2_row0_col6, #T_41dd2_row3_col3, #T_41dd2_row3_col4, #T_41dd2_row4_col5, #T_41dd2_row5_col7, #T_41dd2_row6_col0, #T_41dd2_row7_col1, #T_41dd2_row7_col2 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_41dd2_row0_col7 {
#   background-color: #f7b596;
#   color: #000000;
# }
# #T_41dd2_row1_col2 {
#   background-color: #fffdfc;
#   color: #000000;
# }
# #T_41dd2_row1_col3 {
#   background-color: #f9c6ac;
#   color: #000000;
# }
# #T_41dd2_row1_col5 {
#   background-color: #fbceb7;
#   color: #000000;
# }
# #T_41dd2_row1_col6 {
#   background-color: #e8896c;
#   color: #f1f1f1;
# }
# #T_41dd2_row1_col7, #T_41dd2_row5_col4 {
#   background-color: #df765e;
#   color: #f1f1f1;
# }
# #T_41dd2_row2_col0 {
#   background-color: #ea8e70;
#   color: #f1f1f1;
# }
# #T_41dd2_row2_col1 {
#   background-color: #3c3c3c;
#   color: #f1f1f1;
# }
# #T_41dd2_row2_col3 {
#   background-color: #fef6f1;
#   color: #000000;
# }
# #T_41dd2_row2_col4, #T_41dd2_row6_col6 {
#   background-color: #fbd0b9;
#   color: #000000;
# }
# #T_41dd2_row2_col5 {
#   background-color: #feebdf;
#   color: #000000;
# }
# #T_41dd2_row2_col6 {
#   background-color: #c7c7c7;
#   color: #000000;
# }
# #T_41dd2_row2_col7, #T_41dd2_row3_col0 {
#   background-color: #222222;
#   color: #f1f1f1;
# }
# #T_41dd2_row3_col1 {
#   background-color: #fafafa;
#   color: #000000;
# }
# #T_41dd2_row3_col2 {
#   background-color: #feece1;
#   color: #000000;
# }
# #T_41dd2_row3_col5 {
#   background-color: #fcd3bc;
#   color: #000000;
# }
# #T_41dd2_row3_col6 {
#   background-color: #960f27;
#   color: #f1f1f1;
# }
# #T_41dd2_row3_col7 {
#   background-color: #fee9dd;
#   color: #000000;
# }
# #T_41dd2_row4_col0 {
#   background-color: #930e26;
#   color: #f1f1f1;
# }
# #T_41dd2_row4_col3 {
#   background-color: #fffbfa;
#   color: #000000;
# }
# #T_41dd2_row4_col4 {
#   background-color: #ec9374;
#   color: #f1f1f1;
# }
# #T_41dd2_row4_col6 {
#   background-color: #737373;
#   color: #f1f1f1;
# }
# #T_41dd2_row4_col7, #T_41dd2_row6_col2 {
#   background-color: #c53e3d;
#   color: #f1f1f1;
# }
# #T_41dd2_row5_col0 {
#   background-color: #6c6c6c;
#   color: #f1f1f1;
# }
# #T_41dd2_row5_col1 {
#   background-color: #8d0c25;
#   color: #f1f1f1;
# }
# #T_41dd2_row5_col2 {
#   background-color: #b3b3b3;
#   color: #000000;
# }
# #T_41dd2_row5_col3 {
#   background-color: #fffaf7;
#   color: #000000;
# }
# #T_41dd2_row5_col5 {
#   background-color: #cecece;
#   color: #000000;
# }
# #T_41dd2_row6_col1 {
#   background-color: #1c1c1c;
#   color: #f1f1f1;
# }
# #T_41dd2_row6_col3 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_41dd2_row6_col4 {
#   background-color: #f8bfa4;
#   color: #000000;
# }
# #T_41dd2_row7_col0 {
#   background-color: #d4d4d4;
#   color: #000000;
# }
# #T_41dd2_row7_col4 {
#   background-color: #fddbc7;
#   color: #000000;
# }
# #T_41dd2_row7_col5 {
#   background-color: #fde1d0;
#   color: #000000;
# }
# #T_41dd2_row7_col6 {
#   background-color: #d1d1d1;
#   color: #000000;
# }
# </style>
# <table id="T_41dd2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41dd2_level0_col0" class="col_heading level0 col0" >PC1</th>
#       <th id="T_41dd2_level0_col1" class="col_heading level0 col1" >PC2</th>
#       <th id="T_41dd2_level0_col2" class="col_heading level0 col2" >PC3</th>
#       <th id="T_41dd2_level0_col3" class="col_heading level0 col3" >PC4</th>
#       <th id="T_41dd2_level0_col4" class="col_heading level0 col4" >PC5</th>
#       <th id="T_41dd2_level0_col5" class="col_heading level0 col5" >PC6</th>
#       <th id="T_41dd2_level0_col6" class="col_heading level0 col6" >PC7</th>
#       <th id="T_41dd2_level0_col7" class="col_heading level0 col7" >PC8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41dd2_level0_row0" class="row_heading level0 row0" >Visual Appeal</th>
#       <td id="T_41dd2_row0_col0" class="data row0 col0" >0.480170</td>
#       <td id="T_41dd2_row0_col1" class="data row0 col1" >0.117814</td>
#       <td id="T_41dd2_row0_col2" class="data row0 col2" >0.063320</td>
#       <td id="T_41dd2_row0_col3" class="data row0 col3" >0.730598</td>
#       <td id="T_41dd2_row0_col4" class="data row0 col4" >-0.247014</td>
#       <td id="T_41dd2_row0_col5" class="data row0 col5" >-0.105903</td>
#       <td id="T_41dd2_row0_col6" class="data row0 col6" >-0.375474</td>
#       <td id="T_41dd2_row0_col7" class="data row0 col7" >-0.067539</td>
#     </tr>
#     <tr>
#       <th id="T_41dd2_level0_row1" class="row_heading level0 row1" >Reliability</th>
#       <td id="T_41dd2_row1_col0" class="data row1 col0" >0.494758</td>
#       <td id="T_41dd2_row1_col1" class="data row1 col1" >0.124910</td>
#       <td id="T_41dd2_row1_col2" class="data row1 col2" >-0.002776</td>
#       <td id="T_41dd2_row1_col3" class="data row1 col3" >-0.152447</td>
#       <td id="T_41dd2_row1_col4" class="data row1 col4" >0.819319</td>
#       <td id="T_41dd2_row1_col5" class="data row1 col5" >-0.060484</td>
#       <td id="T_41dd2_row1_col6" class="data row1 col6" >-0.117211</td>
#       <td id="T_41dd2_row1_col7" class="data row1 col7" >-0.166384</td>
#     </tr>
#     <tr>
#       <th id="T_41dd2_level0_row2" class="row_heading level0 row2" >Performance</th>
#       <td id="T_41dd2_row2_col0" class="data row2 col0" >0.128721</td>
#       <td id="T_41dd2_row2_col1" class="data row2 col1" >0.459145</td>
#       <td id="T_41dd2_row2_col2" class="data row2 col2" >0.574833</td>
#       <td id="T_41dd2_row2_col3" class="data row2 col3" >0.005549</td>
#       <td id="T_41dd2_row2_col4" class="data row2 col4" >0.019902</td>
#       <td id="T_41dd2_row2_col5" class="data row2 col5" >0.025704</td>
#       <td id="T_41dd2_row2_col6" class="data row2 col6" >0.288468</td>
#       <td id="T_41dd2_row2_col7" class="data row2 col7" >0.598232</td>
#     </tr>
#     <tr>
#       <th id="T_41dd2_level0_row3" class="row_heading level0 row3" >Service Experience</th>
#       <td id="T_41dd2_row3_col0" class="data row3 col0" >0.486499</td>
#       <td id="T_41dd2_row3_col1" class="data row3 col1" >0.100691</td>
#       <td id="T_41dd2_row3_col2" class="data row3 col2" >-0.054176</td>
#       <td id="T_41dd2_row3_col3" class="data row3 col3" >-0.653781</td>
#       <td id="T_41dd2_row3_col4" class="data row3 col4" >-0.470391</td>
#       <td id="T_41dd2_row3_col5" class="data row3 col5" >-0.052432</td>
#       <td id="T_41dd2_row3_col6" class="data row3 col6" >-0.311210</td>
#       <td id="T_41dd2_row3_col7" class="data row3 col7" >0.044129</td>
#     </tr>
#     <tr>
#       <th id="T_41dd2_level0_row4" class="row_heading level0 row4" >Extra Features</th>
#       <td id="T_41dd2_row4_col0" class="data row4 col0" >0.024373</td>
#       <td id="T_41dd2_row4_col1" class="data row4 col1" >0.519633</td>
#       <td id="T_41dd2_row4_col2" class="data row4 col2" >-0.364578</td>
#       <td id="T_41dd2_row4_col3" class="data row4 col3" >0.023208</td>
#       <td id="T_41dd2_row4_col4" class="data row4 col4" >-0.116821</td>
#       <td id="T_41dd2_row4_col5" class="data row4 col5" >-0.559390</td>
#       <td id="T_41dd2_row4_col6" class="data row4 col6" >0.456829</td>
#       <td id="T_41dd2_row4_col7" class="data row4 col7" >-0.246323</td>
#     </tr>
#     <tr>
#       <th id="T_41dd2_level0_row5" class="row_heading level0 row5" >Comfort</th>
#       <td id="T_41dd2_row5_col0" class="data row5 col0" >0.418255</td>
#       <td id="T_41dd2_row5_col1" class="data row5 col1" >-0.304266</td>
#       <td id="T_41dd2_row5_col2" class="data row5 col2" >0.249807</td>
#       <td id="T_41dd2_row5_col3" class="data row5 col3" >0.020111</td>
#       <td id="T_41dd2_row5_col4" class="data row5 col4" >-0.172621</td>

# %%
# Calculate centroid
index_names = factor_loadings.index

# Plot data points
sns.scatterplot(df_pca, x = 'PC1', y = 'PC2', color = 'grey')

# Plot arrows from centroid to provided coordinates with index names
for i in range(len(factor_loadings['PC1'])):
    plt.arrow(0, 0, factor_loadings['PC1'][i] * 3.5, factor_loadings['PC2'][i] * 3.5, head_width=0.05, head_length=0.1, fc='red', ec='red')
    plt.text((factor_loadings['PC1'][i] * 3.5), factor_loadings['PC2'][i]* 3.5, index_names[i], fontsize=12, ha='center', color = 'red', va = 'center_baseline')

# Set labels and legend
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('A Principal components analysis of the EV 2-Wheeler data set')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-68-a3270d91b779>:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.arrow(0, 0, factor_loadings['PC1'][i] * 3.5, factor_loadings['PC2'][i] * 3.5, head_width=0.05, head_length=0.1, fc='red', ec='red')
# <ipython-input-68-a3270d91b779>:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text((factor_loadings['PC1'][i] * 3.5), factor_loadings['PC2'][i]* 3.5, index_names[i], fontsize=12, ha='center', color = 'red', va = 'center_baseline')

# %%
data_km28 = [KMeans(n_clusters = k, random_state = 42).fit(data_scaled) for k in range(2, 9)]

# %%
wcss = [model.inertia_ for model in data_km28]
fig = plt.figure(figsize = (6,4))
sns.barplot(x = list(range(2, 9)), y = wcss, color = 'grey')
plt.xlabel("Segments")
plt.ylabel('Sum of Within Cluster Distances')
plt.title("Scree plot for the EV 2-Wheeler data set")
plt.show()

# %%
wcss_diff = pd.DataFrame({'Segments':range(2,9),
                          'WCSS Difference': pd.Series(wcss).diff()})
wcss_diff['WCSS Difference'][0] = 0

plt.figure(figsize = (7, 4))
sns.barplot(wcss_diff, x = 'Segments', y = 'WCSS Difference')
plt.show()
# Out:
# <ipython-input-71-38ecbbf4d77b>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   wcss_diff['WCSS Difference'][0] = 0
# <ipython-input-71-38ecbbf4d77b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wcss_diff['WCSS Difference'][0] = 0

# %%
kmeans = data_km28[2]

data_clust = pd.DataFrame(data_scaled, columns = data_segment.columns)
data_clust['cluster'] = kmeans.labels_

data_pca = df_pca.copy()
data_pca['cluster'] = kmeans.labels_

# %% [markdown]
# # Profiling Segments

# %%
data_profile = data_segment.copy()
data_profile['cluster'] = kmeans.labels_

# %%
columns_segment = data_clust.columns
data_pivot = data_profile[columns_segment].groupby('cluster').mean().T

# %%
data_pivot_mean = data_pivot.mean(axis = 1).reset_index()
data_pivot_mean.columns = ['Variable', 'Value']

# %%
plt.figure(figsize = (12, 9))
for i in range(4):
    plt.subplot(2, 2, i+1)
    sns.barplot(data_pivot, x = i, y = data_pivot.index)
    sns.scatterplot(data_pivot_mean, x = 'Value', y = 'Variable', color = 'red')
    for index, row in data_pivot_mean.iterrows():
        plt.hlines(y=row['Variable'], xmin=0, xmax=row['Value'], colors='red', alpha = 0.2)
    plt.ylabel("")
    plt.xlabel("")
    plt.title(f"Cluster {i}: {data_profile['cluster'].value_counts()[i]} ({data_profile['cluster'].value_counts()[i]*100/len(data_profile):.0f}%)")
plt.suptitle("Segment profile plot for the four-segment solution for the EV 2-Wheeler data set", fontsize = 15)
plt.tight_layout()
plt.show()

# %%
# Calculate centroid
index_names = factor_loadings.index

# Plot data points
sns.scatterplot(data_pca, x = 'PC1', y = 'PC2', hue = 'cluster', palette = 'tab10')

# Plot arrows from centroid to provided coordinates with index names
for i in range(len(factor_loadings['PC1'])):
    plt.arrow(0, 0, factor_loadings['PC1'][i] * 3.5, factor_loadings['PC2'][i] * 3.5, head_width=0.05, head_length=0.1, fc='red', ec='red')
    plt.text(factor_loadings['PC1'][i] * 3.5, factor_loadings['PC2'][i]* 3.5, index_names[i], fontsize=12, ha='center', color = 'red', va = 'center_baseline')

# Set labels and legend
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Segment separation plot using principal components 1 and 2')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-77-14c285b91f99>:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.arrow(0, 0, factor_loadings['PC1'][i] * 3.5, factor_loadings['PC2'][i] * 3.5, head_width=0.05, head_length=0.1, fc='red', ec='red')
# <ipython-input-77-14c285b91f99>:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(factor_loadings['PC1'][i] * 3.5, factor_loadings['PC2'][i]* 3.5, index_names[i], fontsize=12, ha='center', color = 'red', va = 'center_baseline')

# %% [markdown]
# # Describing Segments

# %%
data_desc = data.copy()
data_desc['cluster'] = kmeans.labels_

# %%
def mosaicplot(df, color_list, figsize=(5,5), barwidth = 1, title = "Simple Mosaic Plot", xlabel = 'cat'):

    fig, ax = plt.subplots(figsize =figsize)

    # Convert to ratio of each row sum and do a cumsum along row
    p_cnt_ratio_df = df.div(df.sum(1), axis =0)
    ratio_cum_df = p_cnt_ratio_df.cumsum(axis=1)

    # Get column order.
    col_order = ratio_cum_df.columns.tolist()

    x = [str(n) for n in ratio_cum_df.index.tolist()]

    # Do the actual plots
    for col, colour in zip(col_order[::-1], color_list):
        plt.bar(x, ratio_cum_df[col], color=colour, edgecolor='white', width=barwidth, label=col)

    # Add in legend
    plt.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)


    # Configure title and axis
    plt.title(title)
    plt.xlabel("Segments")
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)
    plt.yticks([])
    plt.show()

# %%
color_list = ['#1F77B4', '#FF7F0E', '#2CA02C', '#D62728', '#9467BD', '#8C564B', '#E377C2', '#7F7F7F']

# %%
sentiment_cluster = pd.crosstab(index = data_desc['cluster'], columns = data_desc['sentiment'])
sentiment_cluster
# Out:
# sentiment  negative  neutral  positive
# cluster
# 0                30       41       206
# 1               205        8       118
# 2                16        0        93
# 3                13        4       110

# %%
mosaicplot(sentiment_cluster, color_list[:3], figsize=(6,5), barwidth = 1)

# %%
used_cluster = pd.crosstab(index = data_desc['cluster'], columns = data_desc['Used it for'])

# %%
used_cluster
# Out:
# Used it for  Daily Commute  Everything  Leisure Rides  Occasional Commute  \
# cluster
# 0                      194          55              7                  19
# 1                      245          47              7                  27
# 2                       86          19              2                   1
# 3                       75          39              4                   9
#
# Used it for  Tours
# cluster
# 0                2
# 1                5
# 2                1
# 3                0

# %%
mosaicplot(used_cluster, color_list[:5], figsize=(6,5), barwidth = 1, title = 'Mosaic plot for cross-tabulation of clusters and used it for for the EV 2-Wheelers data set' )

# %%
owned_cluster = pd.crosstab(index = data_desc['cluster'], columns = data_desc['Owned for'])

# %%
mosaicplot(owned_cluster, color_list[:6], figsize=(6,5), barwidth = 1, title = 'Mosaic plot for cross-tabulation of clusters and owned for for the EV 2-Wheelers data set' )

# %%
# Number of cluster along the x-axis and rating along the y-axis
plt.figure(figsize = (5,4))
sns.boxplot(data_desc, x= 'cluster', y = 'rating', palette = 'tab10', width = 0.7)
plt.xlabel("Segments")
plt.ylabel("Rating")
plt.title("Parallel box and whisker plot of age by segment")
plt.savefig("rating.png")
plt.show()
# Out:
# <ipython-input-88-8db23d948315>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data_desc, x= 'cluster', y = 'rating', palette = 'tab10', width = 0.7)

# %%
plt.figure(figsize = (10, 12))
for i, col in enumerate(data_desc.columns[-8:-2]):
    plt.subplot(3, 2, i+1)
    sns.boxplot(data_desc, x = 'cluster', y =col)
    plt.xlabel("Segments", fontsize= 10)
    plt.ylabel(col, fontsize = 10)
    plt.xticks(fontsize = 8)
    plt.yticks(fontsize = 8)
plt.tight_layout()
plt.show()
